# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("retail_sales.csv")

# %%
df
# Out:
#     OrderID CustomerID  Gender  Age         City   OrderDate     Category  \
# 0     O1000       C200  female   49  Los Angeles  2021-02-09  Electronics
# 1     O1001       C201       M   49     new york  2021-09-08  Electronics
# 2     O1002       C202  FEMALE   41     new york  2021-10-04  electronics
# 3     O1003       C203       M   58      chicago  2021-04-07  electronics
# 4     O1004       C204       M   29      chicago  2021-07-18      clothes
# ..      ...        ...     ...  ...          ...         ...          ...
# 195   O1195       C395  FEMALE   33      chicago  2021-06-02      Grocery
# 196   O1196       C396    male   31      Chicago  2021-04-23  electronics
# 197   O1197       C397  female   29           LA  2021-07-10  Electronics
# 198   O1198       C398  FEMALE   40  Los Angeles  2021-07-09  Electronics
# 199   O1199       C399       F   32     New York  2021-04-02  Electronics
#
#      Quantity UnitPrice      Revenue
# 0           1    $45.00          NaN
# ...

# %%
df.head(5)
# Out:
#   OrderID CustomerID  Gender  Age         City   OrderDate     Category  \
# 0   O1000       C200  female   49  Los Angeles  2021-02-09  Electronics
# 1   O1001       C201       M   49     new york  2021-09-08  Electronics
# 2   O1002       C202  FEMALE   41     new york  2021-10-04  electronics
# 3   O1003       C203       M   58      chicago  2021-04-07  electronics
# 4   O1004       C204       M   29      chicago  2021-07-18      clothes
#
#    Quantity UnitPrice      Revenue
# 0         1    $45.00          NaN
# 1         1      5.99   403.834153
# 2         7      5.99  1307.318009
# 3         2     15.49  1096.258492
# 4         5     15.49   915.756061

# %%
df.tail(5)
# Out:
#     OrderID CustomerID  Gender  Age         City   OrderDate     Category  \
# 195   O1195       C395  FEMALE   33      chicago  2021-06-02      Grocery
# 196   O1196       C396    male   31      Chicago  2021-04-23  electronics
# 197   O1197       C397  female   29           LA  2021-07-10  Electronics
# 198   O1198       C398  FEMALE   40  Los Angeles  2021-07-09  Electronics
# 199   O1199       C399       F   32     New York  2021-04-02  Electronics
#
#      Quantity UnitPrice      Revenue
# 195         5     19.99          NaN
# 196         4     49.99  1667.966958
# 197         2     19.99          NaN
# 198         3      5.99  1770.268941
# 199         7    $45.00  1245.233967

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   OrderID     200 non-null    object
#  1   CustomerID  200 non-null    object
#  2   Gender      200 non-null    object
#  3   Age         200 non-null    int64
#  4   City        200 non-null    object
#  5   OrderDate   200 non-null    object
#  6   Category    200 non-null    object
#  7   Quantity    200 non-null    int64
#  8   UnitPrice   200 non-null    object
#  9   Revenue     174 non-null    float64
# dtypes: float64(1), int64(2), object(7)
# memory usage: 15.8+ KB

# %%
df["Gender"]=df["Gender"].str.strip().str.upper()

# %%
df
# Out:
#     OrderID CustomerID  Gender  Age         City   OrderDate     Category  \
# 0     O1000       C200  FEMALE   49  Los Angeles  2021-02-09  Electronics
# 1     O1001       C201       M   49     new york  2021-09-08  Electronics
# 2     O1002       C202  FEMALE   41     new york  2021-10-04  electronics
# 3     O1003       C203       M   58      chicago  2021-04-07  electronics
# 4     O1004       C204       M   29      chicago  2021-07-18      clothes
# ..      ...        ...     ...  ...          ...         ...          ...
# 195   O1195       C395  FEMALE   33      chicago  2021-06-02      Grocery
# 196   O1196       C396    MALE   31      Chicago  2021-04-23  electronics
# 197   O1197       C397  FEMALE   29           LA  2021-07-10  Electronics
# 198   O1198       C398  FEMALE   40  Los Angeles  2021-07-09  Electronics
# 199   O1199       C399       F   32     New York  2021-04-02  Electronics
#
#      Quantity UnitPrice      Revenue
# 0           1    $45.00          NaN
# ...

# %%
df["Gender"] = df["Gender"].replace("FEMALE", "F")

# %%
df
# Out:
#     OrderID CustomerID Gender  Age         City   OrderDate     Category  \
# 0     O1000       C200      F   49  Los Angeles  2021-02-09  Electronics
# 1     O1001       C201      M   49     new york  2021-09-08  Electronics
# 2     O1002       C202      F   41     new york  2021-10-04  electronics
# 3     O1003       C203      M   58      chicago  2021-04-07  electronics
# 4     O1004       C204      M   29      chicago  2021-07-18      clothes
# ..      ...        ...    ...  ...          ...         ...          ...
# 195   O1195       C395      F   33      chicago  2021-06-02      Grocery
# 196   O1196       C396   MALE   31      Chicago  2021-04-23  electronics
# 197   O1197       C397      F   29           LA  2021-07-10  Electronics
# 198   O1198       C398      F   40  Los Angeles  2021-07-09  Electronics
# 199   O1199       C399      F   32     New York  2021-04-02  Electronics
#
#      Quantity UnitPrice      Revenue
# 0           1    $45.00          NaN
# ...

# %%
df["Gender"] = df["Gender"].replace("MALE", "M")

# %%
df
# Out:
#     OrderID CustomerID Gender  Age         City   OrderDate     Category  \
# 0     O1000       C200      F   49  Los Angeles  2021-02-09  Electronics
# 1     O1001       C201      M   49     new york  2021-09-08  Electronics
# 2     O1002       C202      F   41     new york  2021-10-04  electronics
# 3     O1003       C203      M   58      chicago  2021-04-07  electronics
# 4     O1004       C204      M   29      chicago  2021-07-18      clothes
# ..      ...        ...    ...  ...          ...         ...          ...
# 195   O1195       C395      F   33      chicago  2021-06-02      Grocery
# 196   O1196       C396      M   31      Chicago  2021-04-23  electronics
# 197   O1197       C397      F   29           LA  2021-07-10  Electronics
# 198   O1198       C398      F   40  Los Angeles  2021-07-09  Electronics
# 199   O1199       C399      F   32     New York  2021-04-02  Electronics
#
#      Quantity UnitPrice      Revenue
# 0           1    $45.00          NaN
# ...

# %%
df.duplicated("OrderID").sum()
# Out:
# np.int64(0)

# %%
df.duplicated("CustomerID").sum()
# Out:
# np.int64(0)

# %%
df["Age"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["Revenue"].isnull().sum()
# Out:
# np.int64(26)

# %%
df = df.dropna()

# %%
df["Category"]= df["Category"].str.strip().str.upper()
df["City"]= df["City"].str.strip().str.upper()
# Out:
# /var/folders/k9/wb13j1lj4k70df7f64h2vn900000gn/T/ipykernel_1613/1405454543.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Category"]= df["Category"].str.strip().str.upper()
# /var/folders/k9/wb13j1lj4k70df7f64h2vn900000gn/T/ipykernel_1613/1405454543.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["City"]= df["City"].str.strip().str.upper()

# %%
df
# Out:
#     OrderID CustomerID Gender  Age         City   OrderDate     Category  \
# 1     O1001       C201      M   49     NEW YORK  2021-09-08  ELECTRONICS
# 2     O1002       C202      F   41     NEW YORK  2021-10-04  ELECTRONICS
# 3     O1003       C203      M   58      CHICAGO  2021-04-07  ELECTRONICS
# 4     O1004       C204      M   29      CHICAGO  2021-07-18      CLOTHES
# 5     O1005       C205      M   56      CHICAGO  2021-04-21      GROCERY
# ..      ...        ...    ...  ...          ...         ...          ...
# 193   O1193       C393      M   25     NEW YORK  2021-06-10  ELECTRONICS
# 194   O1194       C394      M   63      CHICAGO  2021-02-25      CLOTHES
# 196   O1196       C396      M   31      CHICAGO  2021-04-23  ELECTRONICS
# 198   O1198       C398      F   40  LOS ANGELES  2021-07-09  ELECTRONICS
# 199   O1199       C399      F   32     NEW YORK  2021-04-02  ELECTRONICS
#
#      Quantity UnitPrice      Revenue
# 1           1      5.99   403.834153
# ...

# %%
df["UnitPrice"]=df["UnitPrice"].replace(r'[\$]', '', regex=True)
# Out:
# /var/folders/k9/wb13j1lj4k70df7f64h2vn900000gn/T/ipykernel_1613/3972156544.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["UnitPrice"]=df["UnitPrice"].replace(r'[\$]', '', regex=True)

# %%
df
# Out:
#     OrderID CustomerID Gender  Age         City   OrderDate     Category  \
# 1     O1001       C201      M   49     NEW YORK  2021-09-08  ELECTRONICS
# 2     O1002       C202      F   41     NEW YORK  2021-10-04  ELECTRONICS
# 3     O1003       C203      M   58      CHICAGO  2021-04-07  ELECTRONICS
# 4     O1004       C204      M   29      CHICAGO  2021-07-18      CLOTHES
# 5     O1005       C205      M   56      CHICAGO  2021-04-21      GROCERY
# ..      ...        ...    ...  ...          ...         ...          ...
# 193   O1193       C393      M   25     NEW YORK  2021-06-10  ELECTRONICS
# 194   O1194       C394      M   63      CHICAGO  2021-02-25      CLOTHES
# 196   O1196       C396      M   31      CHICAGO  2021-04-23  ELECTRONICS
# 198   O1198       C398      F   40  LOS ANGELES  2021-07-09  ELECTRONICS
# 199   O1199       C399      F   32     NEW YORK  2021-04-02  ELECTRONICS
#
#      Quantity UnitPrice      Revenue
# 1           1      5.99   403.834153
# ...

# %%
df["UnitPrice"] = df["UnitPrice"].replace(r"[^\d.]", "", regex=True).astype(float)
df["Revenue"] = df["Revenue"].replace(r"[^\d.]", "", regex=True).astype(float)
# Out:
# /var/folders/k9/wb13j1lj4k70df7f64h2vn900000gn/T/ipykernel_1613/3487382732.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["UnitPrice"] = df["UnitPrice"].replace(r"[^\d.]", "", regex=True).astype(float)
# /var/folders/k9/wb13j1lj4k70df7f64h2vn900000gn/T/ipykernel_1613/3487382732.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Revenue"] = df["Revenue"].replace(r"[^\d.]", "", regex=True).astype(float)

# %%
df
# Out:
#     OrderID CustomerID Gender  Age         City   OrderDate     Category  \
# 1     O1001       C201      M   49     NEW YORK  2021-09-08  ELECTRONICS
# 2     O1002       C202      F   41     NEW YORK  2021-10-04  ELECTRONICS
# 3     O1003       C203      M   58      CHICAGO  2021-04-07  ELECTRONICS
# 4     O1004       C204      M   29      CHICAGO  2021-07-18      CLOTHES
# 5     O1005       C205      M   56      CHICAGO  2021-04-21      GROCERY
# ..      ...        ...    ...  ...          ...         ...          ...
# 193   O1193       C393      M   25     NEW YORK  2021-06-10  ELECTRONICS
# 194   O1194       C394      M   63      CHICAGO  2021-02-25      CLOTHES
# 196   O1196       C396      M   31      CHICAGO  2021-04-23  ELECTRONICS
# 198   O1198       C398      F   40  LOS ANGELES  2021-07-09  ELECTRONICS
# 199   O1199       C399      F   32     NEW YORK  2021-04-02  ELECTRONICS
#
#      Quantity  UnitPrice      Revenue
# 1           1       5.99   403.834153
# ...

# %%
df["OrderDate"] = pd.to_datetime(df["OrderDate"], format= "mixed")
# Out:
# /var/folders/k9/wb13j1lj4k70df7f64h2vn900000gn/T/ipykernel_1613/2557354682.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["OrderDate"] = pd.to_datetime(df["OrderDate"], format= "mixed")

# %%
df
# Out:
#     OrderID CustomerID Gender  Age         City  OrderDate     Category  \
# 1     O1001       C201      M   49     NEW YORK 2021-09-08  ELECTRONICS
# 2     O1002       C202      F   41     NEW YORK 2021-10-04  ELECTRONICS
# 3     O1003       C203      M   58      CHICAGO 2021-04-07  ELECTRONICS
# 4     O1004       C204      M   29      CHICAGO 2021-07-18      CLOTHES
# 5     O1005       C205      M   56      CHICAGO 2021-04-21      GROCERY
# ..      ...        ...    ...  ...          ...        ...          ...
# 193   O1193       C393      M   25     NEW YORK 2021-06-10  ELECTRONICS
# 194   O1194       C394      M   63      CHICAGO 2021-02-25      CLOTHES
# 196   O1196       C396      M   31      CHICAGO 2021-04-23  ELECTRONICS
# 198   O1198       C398      F   40  LOS ANGELES 2021-07-09  ELECTRONICS
# 199   O1199       C399      F   32     NEW YORK 2021-04-02  ELECTRONICS
#
#      Quantity  UnitPrice      Revenue
# 1           1       5.99   403.834153
# ...

# %%
df.columns
# Out:
# Index(['OrderID', 'CustomerID', 'Gender', 'Age', 'City', 'OrderDate',
#        'Category', 'Quantity', 'UnitPrice', 'Revenue'],
#       dtype='object')

# %%
df.groupby("Category")["Revenue"].idxmax()
# Out:
# Category
# CLOTHES        129
# CLOTHING        55
# ELECTRONICS    128
# GROCERIES      170
# GROCERY         90
# Name: Revenue, dtype: int64

# %%
df.groupby("Category")["Revenue"].mean().idxmax()
# Out:
# 'CLOTHING'

# %%
df.groupby("CustomerID")["Revenue"].idxmax().idxmax()
# Out:
# 'C399'

# %%
df.groupby("City")["Revenue"].idxmax().idxmax()
# Out:
# 'CHICAGO'

# %%
df.groupby("OrderDate")["Revenue"].idxmax().idxmax()
# Out:
# Timestamp('2021-04-02 00:00:00')
